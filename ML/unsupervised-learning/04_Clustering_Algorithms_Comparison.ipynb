# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN, KMeans, AgglomerativeClustering

# %%
x,y = make_moons(n_samples=500, noise=0.05)
scaler = StandardScaler()
x_scale = scaler.fit_transform(x)

# %%
plt.scatter(x_scale[:,0], x_scale[:,1])

# %%
kmeans = KMeans(n_clusters=2)
Agg_cluster = AgglomerativeClustering(n_clusters=2, linkage='ward')
Dbscan = DBSCAN(min_samples=4 ,eps=0.5)

# %%
kmeans.fit(x_scale)
Agg_cluster.fit(x_scale)
Dbscan.fit(x_scale)
# Out:
# DBSCAN(min_samples=4)

# %%
plt.scatter(x_scale[:,0], x_scale[:,1], c=kmeans.labels_)

# %%
plt.scatter(x_scale[:,0], x_scale[:,1], c=Agg_cluster.labels_)

# %%
plt.scatter(x_scale[:,0], x_scale[:,1], c=Dbscan.labels_)

# %%
from sklearn.metrics import silhouette_score

# %%
print("silhouette_score:",silhouette_score(x_scale, kmeans.labels_))
# Out:
# silhouette_score: 0.49572691584422884

# %%
print("silhouette_score:",silhouette_score(x_scale, Agg_cluster.labels_))
# Out:
# silhouette_score: 0.46343185431375805

# %%
print("silhouette_score: ",silhouette_score(x_scale, Dbscan.labels_))
# Out:
# silhouette_score:  0.39046939629093536
