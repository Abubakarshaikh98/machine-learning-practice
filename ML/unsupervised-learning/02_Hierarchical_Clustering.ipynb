# %% [markdown]
# # Heirarchical_Clustering

# %% [markdown]
# Heirachical clustering is a method for grouping data into disjoint subsets of similar data. It is a non-parametric method that is used when the number of clusters is not known in advance. It is also used to find clusters in data that is not normally distributed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(n_samples=300, centers=3, random_state=42)

# %%
plt.scatter(x[:,0], x[:,1], c=y, cmap='rainbow')

# %%
import scipy.cluster.hierarchy as sch

# %%
sc_dendrogram = sch.dendrogram(sch.linkage(x, method='ward'))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')

# %%
labels = clustering.fit_predict(x)

# %%
plt.scatter(x[:,0], x[:,1], c=y, cmap='rainbow')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-7.33898809, -7.72995396],
#        [-7.74004056, -7.26466514],
#        [-1.68665271,  7.79344248],
#        [ 4.42219763,  3.07194654],
#        [-8.91775173, -7.8881959 ],
#        [ 5.49753846,  1.81323115],
#        [-2.3360167 ,  9.39960351],
#        [ 5.05281029,  1.40944513],
#        [-2.98837186,  8.82862715],
#        [-3.70050112,  9.67083974],
#        [-3.11090424, 10.86656431],
#        [ 4.99689432,  1.28026009],
#        [-2.30033403,  7.054616  ],
#        [-3.92456837,  8.59364081],
#        [-7.53026976, -7.36723498],
#        [-3.21125072,  8.68662398],
#        [-8.50716963, -6.83202465],
#        [ 2.61473625,  2.159624  ],
#        [-2.41212007,  9.98293112],
#        [-1.92234053, 11.20474175],
#        [-1.35060204,  8.19360381],
#        [-2.67048333,  9.41833699],
#        [ 5.61499857,  1.8261123 ],
#        [-6.99195524, -7.10107919],
#        [-2.97261532,  8.54855637],
#        [-6.34982301, -5.43854097],
#        [-7.45639852, -6.12471837],
# ...

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris().data

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
scaler = StandardScaler()
iris_scaled = scaler.fit_transform(iris)

# %%
iris_scaled
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
plt.figure(figsize=(12,10))
sch.dendrogram(sch.linkage(iris_scaled, method='ward'))
plt.show()

# %%
iris_cluster_agg = AgglomerativeClustering(n_clusters=3, linkage='ward')

# %%
iris_labels = iris_cluster_agg.fit_predict(iris_scaled)

# %%
plt.scatter(iris[:,0], iris[:,1], c=iris_labels)
